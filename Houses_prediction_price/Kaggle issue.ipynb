# %%
import os
import warnings
warnings.simplefilter(action = 'ignore', category=FutureWarning)
warnings.filterwarnings('ignore')
def ignore_warn(*args, **kwargs):
    pass

warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)

import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '{:.3f}'.format(x)) #Limiting floats output to 3 decimal points
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="ticks", color_codes=True, font_scale=1.5)
color = sns.color_palette()
sns.set_style('darkgrid')
import mpl_toolkits
from mpl_toolkits.mplot3d import Axes3D
import pylab 

from scipy import stats
from scipy.stats import skew, norm, probplot, boxcox
from scipy.special import boxcox1p
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import RobustScaler, PolynomialFeatures, StandardScaler, LabelEncoder
from sklearn.feature_selection import f_regression, mutual_info_regression, SelectKBest, RFECV, SelectFromModel
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.feature_extraction import FeatureHasher
from sklearn.decomposition import PCA, KernelPCA
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import LinearRegression, OrthogonalMatchingPursuit, Lasso, LassoLarsIC, ElasticNet, ElasticNetCV
from sklearn.linear_model import SGDRegressor, PassiveAggressiveRegressor, HuberRegressor, BayesianRidge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor
import xgboost as xgb
from xgboost import XGBRegressor, plot_importance
import lightgbm as lgb

from sklearn.model_selection import GridSearchCV, cross_val_score, KFold, cross_val_predict, train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-85dc3be93a99> in <module>
#      30 from sklearn.preprocessing import RobustScaler, PolynomialFeatures, StandardScaler, LabelEncoder
#      31 from sklearn.feature_selection import f_regression, mutual_info_regression, SelectKBest, RFECV, SelectFromModel
# ---> 32 from mlxtend.feature_selection import SequentialFeatureSelector as SFS
#      33 from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
#      34 from sklearn.feature_extraction import FeatureHasher
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
data = pd.read_csv('data.csv')

# %%
data.drop("Id", axis = 1, inplace = True)

# %%
# Function to estimate the dataset
def rstr(df, pred=None): 
    obs = df.shape[0]
    types = df.dtypes
    counts = df.apply(lambda x: x.count())
    uniques = df.apply(lambda x: [x.unique()])
    nulls = df.apply(lambda x: x.isnull().sum())
    distincts = df.apply(lambda x: x.unique().shape[0])
    missing_ration = (df.isnull().sum()/ obs) * 100
    skewness = df.skew()
    kurtosis = df.kurt() 
    print('Data shape:', df.shape)
    
    if pred is None:
        cols = ['types', 'counts', 'distincts', 'nulls', 'missing ration', 'uniques', 'skewness', 'kurtosis']
        str = pd.concat([types, counts, distincts, nulls, missing_ration, uniques, skewness, kurtosis], axis = 1)

    else:
        corr = df.corr()[pred]
        str = pd.concat([types, counts, distincts, nulls, missing_ration, uniques, skewness, kurtosis, corr], axis = 1, sort=False)
        corr_col = 'corr '  + pred
        cols = ['types', 'counts', 'distincts', 'nulls', 'missing_ration', 'uniques', 'skewness', 'kurtosis', corr_col ]
    
    str.columns = cols
    dtypes = str.types.value_counts()
    print('___________________________\nData types:\n',str.types.value_counts())
    print('___________________________')
    return str

# %%
details = rstr(data, 'SalePrice')
display(details.sort_values(by='corr SalePrice', ascending=False))
# Out:
# Data shape: (1460, 80)
# ___________________________
# Data types:
#  object     43
# int64      34
# float64     3
# Name: types, dtype: int64
# ___________________________
#                  types  counts  distincts  nulls  missing_ration  \
# SalePrice        int64    1460        663      0           0.000
# OverallQual      int64    1460         10      0           0.000
# GrLivArea        int64    1460        861      0           0.000
# GarageCars       int64    1460          5      0           0.000
# GarageArea       int64    1460        441      0           0.000
# TotalBsmtSF      int64    1460        721      0           0.000
# 1stFlrSF         int64    1460        753      0           0.000
# FullBath         int64    1460          4      0           0.000
# TotRmsAbvGrd     int64    1460         12      0           0.000
# YearBuilt        int64    1460        112      0           0.000
# YearRemodAdd     int64    1460         61      0           0.000
# GarageYrBlt    float64    1379         98     81           5.548
# MasVnrArea     float64    1452        328      8           0.548
# Fireplaces       int64    1460          4      0           0.000
# BsmtFinSF1       int64    1460        637      0           0.000
# LotFrontage    float64    1201        111    259          17.740
# WoodDeckSF       int64    1460        274      0           0.000
# 2ndFlrSF         int64    1460        417      0           0.000
# OpenPorchSF      int64    1460        202      0           0.000
# HalfBath         int64    1460          3      0           0.000
# LotArea          int64    1460       1073      0           0.000
# BsmtFullBath     int64    1460          4      0           0.000
# BsmtUnfSF        int64    1460        780      0           0.000
# BedroomAbvGr     int64    1460          8      0           0.000
# ScreenPorch      int64    1460         76      0           0.000
# PoolArea         int64    1460          8      0           0.000
# MoSold           int64    1460         12      0           0.000
# 3SsnPorch        int64    1460         20      0           0.000
# BsmtFinSF2       int64    1460        144      0           0.000
# BsmtHalfBath     int64    1460          3      0           0.000
# ...                ...     ...        ...    ...             ...
# RoofStyle       object    1460          6      0           0.000
# RoofMatl        object    1460          8      0           0.000
# Exterior1st     object    1460         15      0           0.000
# Exterior2nd     object    1460         16      0           0.000
# MasVnrType      object    1452          5      8           0.548
# ExterQual       object    1460          4      0           0.000
# ExterCond       object    1460          5      0           0.000
# Foundation      object    1460          6      0           0.000
# BsmtQual        object    1423          5     37           2.534
# BsmtCond        object    1423          5     37           2.534
# BsmtExposure    object    1422          5     38           2.603
# BsmtFinType1    object    1423          7     37           2.534
# BsmtFinType2    object    1422          7     38           2.603
# Heating         object    1460          6      0           0.000
# HeatingQC       object    1460          5      0           0.000
# CentralAir      object    1460          2      0           0.000
# Electrical      object    1459          6      1           0.068
# KitchenQual     object    1460          4      0           0.000
# Functional      object    1460          7      0           0.000
# FireplaceQu     object     770          6    690          47.260
# GarageType      object    1379          7     81           5.548
# GarageFinish    object    1379          4     81           5.548
# GarageQual      object    1379          6     81           5.548
# GarageCond      object    1379          6     81           5.548
# PavedDrive      object    1460          3      0           0.000
# PoolQC          object       7          4   1453          99.521
# Fence           object     281          5   1179          80.753
# MiscFeature     object      54          5   1406          96.301
# SaleType        object    1460          9      0           0.000
# SaleCondition   object    1460          6      0           0.000
#
#                                                          uniques  skewness  \
# SalePrice      [[208500, 181500, 223500, 140000, 250000, 1430...     1.883
# OverallQual                    [[7, 6, 8, 5, 9, 4, 10, 3, 1, 2]]     0.217
# GrLivArea      [[1710, 1262, 1786, 1717, 2198, 1362, 1694, 20...     1.367
# GarageCars                                     [[2, 3, 1, 0, 4]]    -0.343
# GarageArea     [[548, 460, 608, 642, 836, 480, 636, 484, 468,...     0.180
# TotalBsmtSF    [[856, 1262, 920, 756, 1145, 796, 1686, 1107, ...     1.524
# 1stFlrSF       [[856, 1262, 920, 961, 1145, 796, 1694, 1107, ...     1.377
# FullBath                                          [[2, 1, 3, 0]]     0.037
# TotRmsAbvGrd          [[8, 6, 7, 9, 5, 11, 4, 10, 12, 3, 2, 14]]     0.676
# YearBuilt      [[2003, 1976, 2001, 1915, 2000, 1993, 2004, 19...    -0.613
# YearRemodAdd   [[2003, 1976, 2002, 1970, 2000, 1995, 2005, 19...    -0.504
# GarageYrBlt    [[2003.0, 1976.0, 2001.0, 1998.0, 2000.0, 1993...    -0.649
# MasVnrArea     [[196.0, 0.0, 162.0, 350.0, 186.0, 240.0, 286....     2.669
# Fireplaces                                        [[0, 1, 2, 3]]     0.650
# BsmtFinSF1     [[706, 978, 486, 216, 655, 732, 1369, 859, 0, ...     1.686
# LotFrontage    [[65.0, 80.0, 68.0, 60.0, 84.0, 85.0, 75.0, na...     2.164
# WoodDeckSF     [[0, 298, 192, 40, 255, 235, 90, 147, 140, 160...     1.541
# 2ndFlrSF       [[854, 0, 866, 756, 1053, 566, 983, 752, 1142,...     0.813
# OpenPorchSF    [[61, 0, 42, 35, 84, 30, 57, 204, 4, 21, 33, 2...     2.364
# HalfBath                                             [[1, 0, 2]]     0.676
# LotArea        [[8450, 9600, 11250, 9550, 14260, 14115, 10084...    12.208
# BsmtFullBath                                      [[1, 0, 2, 3]]     0.596
# BsmtUnfSF      [[150, 284, 434, 540, 490, 64, 317, 216, 952, ...     0.920
# BedroomAbvGr                          [[3, 4, 1, 2, 0, 5, 6, 8]]     0.212
# ScreenPorch    [[0, 176, 198, 291, 252, 99, 184, 168, 130, 14...     4.122
# PoolArea                [[0, 512, 648, 576, 555, 480, 519, 738]]    14.828
# MoSold                 [[2, 5, 9, 12, 10, 8, 11, 4, 1, 7, 3, 6]]     0.212
# 3SsnPorch      [[0, 320, 407, 130, 180, 168, 140, 508, 238, 2...    10.304
# BsmtFinSF2     [[0, 32, 668, 486, 93, 491, 506, 712, 362, 41,...     4.255
# BsmtHalfBath                                         [[0, 1, 2]]     4.103
# ...                                                          ...       ...
# RoofStyle           [[Gable, Hip, Gambrel, Mansard, Flat, Shed]]       nan
# RoofMatl       [[CompShg, WdShngl, Metal, WdShake, Membran, T...       nan
# Exterior1st    [[VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace,...       nan
# Exterior2nd    [[VinylSd, MetalSd, Wd Shng, HdBoard, Plywood,...       nan
# MasVnrType                 [[BrkFace, None, Stone, BrkCmn, nan]]       nan
# ExterQual                                     [[Gd, TA, Ex, Fa]]       nan
# ExterCond                                 [[TA, Gd, Fa, Po, Ex]]       nan
# Foundation          [[PConc, CBlock, BrkTil, Wood, Slab, Stone]]       nan
# BsmtQual                                 [[Gd, TA, Ex, nan, Fa]]       nan
# BsmtCond                                 [[TA, Gd, nan, Fa, Po]]       nan
# BsmtExposure                             [[No, Gd, Mn, Av, nan]]       nan
# BsmtFinType1               [[GLQ, ALQ, Unf, Rec, BLQ, nan, LwQ]]       nan
# BsmtFinType2               [[Unf, BLQ, nan, ALQ, Rec, LwQ, GLQ]]       nan
# Heating                  [[GasA, GasW, Grav, Wall, OthW, Floor]]       nan
# HeatingQC                                 [[Ex, Gd, TA, Fa, Po]]       nan
# CentralAir                                              [[Y, N]]       nan
# Electrical              [[SBrkr, FuseF, FuseA, FuseP, Mix, nan]]       nan
# KitchenQual                                   [[Gd, TA, Ex, Fa]]       nan
# Functional             [[Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]]       nan
# FireplaceQu                          [[nan, TA, Gd, Fa, Ex, Po]]       nan
# GarageType     [[Attchd, Detchd, BuiltIn, CarPort, nan, Basme...       nan
# GarageFinish                              [[RFn, Unf, Fin, nan]]       nan
# GarageQual                           [[TA, Fa, Gd, nan, Ex, Po]]       nan
# GarageCond                           [[TA, Fa, nan, Gd, Po, Ex]]       nan
# PavedDrive                                           [[Y, N, P]]       nan
# PoolQC                                       [[nan, Ex, Fa, Gd]]       nan
# Fence                          [[nan, MnPrv, GdWo, GdPrv, MnWw]]       nan
# MiscFeature                      [[nan, Shed, Gar2, Othr, TenC]]       nan
# SaleType       [[WD, New, COD, ConLD, ConLI, CWD, ConLw, Con,...       nan
# SaleCondition  [[Normal, Abnorml, Partial, AdjLand, Alloca, F...       nan
#
#                kurtosis  corr SalePrice
# SalePrice         6.536           1.000
# OverallQual       0.096           0.791
# GrLivArea         4.895           0.709
# GarageCars        0.221           0.640
# GarageArea        0.917           0.623
# TotalBsmtSF      13.250           0.614
# 1stFlrSF          5.746           0.606
# FullBath         -0.857           0.561
# TotRmsAbvGrd      0.881           0.534
# YearBuilt        -0.440           0.523
# YearRemodAdd     -1.272           0.507
# GarageYrBlt      -0.418           0.486
# MasVnrArea       10.082           0.477
# Fireplaces       -0.217           0.467
# BsmtFinSF1       11.118           0.386
# LotFrontage      17.453           0.352
# WoodDeckSF        2.993           0.324
# 2ndFlrSF         -0.553           0.319
# OpenPorchSF       8.490           0.316
# HalfBath         -1.077           0.284
# LotArea         203.243           0.264
# BsmtFullBath     -0.839           0.227
# BsmtUnfSF         0.475           0.214
# BedroomAbvGr      2.231           0.168
# ScreenPorch      18.439           0.111
# PoolArea        223.268           0.092
# MoSold           -0.404           0.046
# 3SsnPorch       123.662           0.045
# BsmtFinSF2       20.113          -0.011
# BsmtHalfBath     16.397          -0.017
# ...                 ...             ...
# RoofStyle           nan             nan
# RoofMatl            nan             nan
# Exterior1st         nan             nan
# Exterior2nd         nan             nan
# MasVnrType          nan             nan
# ExterQual           nan             nan
# ExterCond           nan             nan
# Foundation          nan             nan
# BsmtQual            nan             nan
# BsmtCond            nan             nan
# BsmtExposure        nan             nan
# BsmtFinType1        nan             nan
# BsmtFinType2        nan             nan
# Heating             nan             nan
# HeatingQC           nan             nan
# CentralAir          nan             nan
# Electrical          nan             nan
# KitchenQual         nan             nan
# Functional          nan             nan
# FireplaceQu         nan             nan
# GarageType          nan             nan
# GarageFinish        nan             nan
# GarageQual          nan             nan
# GarageCond          nan             nan
# PavedDrive          nan             nan
# PoolQC              nan             nan
# Fence               nan             nan
# MiscFeature         nan             nan
# SaleType            nan             nan
# SaleCondition       nan             nan
#
# [80 rows x 9 columns]

# %%
display(data.describe().transpose())
# Out:
#                  count       mean       std       min        25%        50%  \
# MSSubClass    1460.000     56.897    42.301    20.000     20.000     50.000
# LotFrontage   1201.000     70.050    24.285    21.000     59.000     69.000
# LotArea       1460.000  10516.828  9981.265  1300.000   7553.500   9478.500
# OverallQual   1460.000      6.099     1.383     1.000      5.000      6.000
# OverallCond   1460.000      5.575     1.113     1.000      5.000      5.000
# YearBuilt     1460.000   1971.268    30.203  1872.000   1954.000   1973.000
# YearRemodAdd  1460.000   1984.866    20.645  1950.000   1967.000   1994.000
# MasVnrArea    1452.000    103.685   181.066     0.000      0.000      0.000
# BsmtFinSF1    1460.000    443.640   456.098     0.000      0.000    383.500
# BsmtFinSF2    1460.000     46.549   161.319     0.000      0.000      0.000
# BsmtUnfSF     1460.000    567.240   441.867     0.000    223.000    477.500
# TotalBsmtSF   1460.000   1057.429   438.705     0.000    795.750    991.500
# 1stFlrSF      1460.000   1162.627   386.588   334.000    882.000   1087.000
# 2ndFlrSF      1460.000    346.992   436.528     0.000      0.000      0.000
# LowQualFinSF  1460.000      5.845    48.623     0.000      0.000      0.000
# GrLivArea     1460.000   1515.464   525.480   334.000   1129.500   1464.000
# BsmtFullBath  1460.000      0.425     0.519     0.000      0.000      0.000
# BsmtHalfBath  1460.000      0.058     0.239     0.000      0.000      0.000
# FullBath      1460.000      1.565     0.551     0.000      1.000      2.000
# HalfBath      1460.000      0.383     0.503     0.000      0.000      0.000
# BedroomAbvGr  1460.000      2.866     0.816     0.000      2.000      3.000
# KitchenAbvGr  1460.000      1.047     0.220     0.000      1.000      1.000
# TotRmsAbvGrd  1460.000      6.518     1.625     2.000      5.000      6.000
# Fireplaces    1460.000      0.613     0.645     0.000      0.000      1.000
# GarageYrBlt   1379.000   1978.506    24.690  1900.000   1961.000   1980.000
# GarageCars    1460.000      1.767     0.747     0.000      1.000      2.000
# GarageArea    1460.000    472.980   213.805     0.000    334.500    480.000
# WoodDeckSF    1460.000     94.245   125.339     0.000      0.000      0.000
# OpenPorchSF   1460.000     46.660    66.256     0.000      0.000     25.000
# EnclosedPorch 1460.000     21.954    61.119     0.000      0.000      0.000
# 3SsnPorch     1460.000      3.410    29.317     0.000      0.000      0.000
# ScreenPorch   1460.000     15.061    55.757     0.000      0.000      0.000
# PoolArea      1460.000      2.759    40.177     0.000      0.000      0.000
# MiscVal       1460.000     43.489   496.123     0.000      0.000      0.000
# MoSold        1460.000      6.322     2.704     1.000      5.000      6.000
# YrSold        1460.000   2007.816     1.328  2006.000   2007.000   2008.000
# SalePrice     1460.000 180921.196 79442.503 34900.000 129975.000 163000.000
#
#                      75%        max
# MSSubClass        70.000    190.000
# LotFrontage       80.000    313.000
# LotArea        11601.500 215245.000
# OverallQual        7.000     10.000
# OverallCond        6.000      9.000
# YearBuilt       2000.000   2010.000
# YearRemodAdd    2004.000   2010.000
# MasVnrArea       166.000   1600.000
# BsmtFinSF1       712.250   5644.000
# BsmtFinSF2         0.000   1474.000
# BsmtUnfSF        808.000   2336.000
# TotalBsmtSF     1298.250   6110.000
# 1stFlrSF        1391.250   4692.000
# 2ndFlrSF         728.000   2065.000
# LowQualFinSF       0.000    572.000
# GrLivArea       1776.750   5642.000
# BsmtFullBath       1.000      3.000
# BsmtHalfBath       0.000      2.000
# FullBath           2.000      3.000
# HalfBath           1.000      2.000
# BedroomAbvGr       3.000      8.000
# KitchenAbvGr       1.000      3.000
# TotRmsAbvGrd       7.000     14.000
# Fireplaces         1.000      3.000
# GarageYrBlt     2002.000   2010.000
# GarageCars         2.000      4.000
# GarageArea       576.000   1418.000
# WoodDeckSF       168.000    857.000
# OpenPorchSF       68.000    547.000
# EnclosedPorch      0.000    552.000
# 3SsnPorch          0.000    508.000
# ScreenPorch        0.000    480.000
# PoolArea           0.000    738.000
# MiscVal            0.000  15500.000
# MoSold             8.000     12.000
# YrSold          2009.000   2010.000
# SalePrice     214000.000 755000.000

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
for i in data.columns:
    if type(i) == object:
        print(i)

# %%
type(data['MSSubClass'])
# Out:
# pandas.core.series.Series

# %%
data['Exterior2nd'].dtypes
# Out:
# dtype('O')

# %%
cat_features = []
for i in data.columns:
    if (data[i].dtypes == object):
        print(i)
        cat_features.append(i)
print(cat_features)
# Out:
# MSZoning
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive
# PoolQC
# Fence
# MiscFeature
# SaleType
# SaleCondition
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %%
data_1 = data.drop(cat_features, axis=1)

# %%
data_1.shape
# Out:
# (1460, 37)

# %%
details = rstr(data, 'SalePrice')
display(details.sort_values(by='corr SalePrice', ascending=False))
# Out:
# Data shape: (1460, 80)
# ___________________________
# Data types:
#  object     43
# int64      34
# float64     3
# Name: types, dtype: int64
# ___________________________
#                  types  counts  distincts  nulls  missing_ration  \
# SalePrice        int64    1460        663      0           0.000
# OverallQual      int64    1460         10      0           0.000
# GrLivArea        int64    1460        861      0           0.000
# GarageCars       int64    1460          5      0           0.000
# GarageArea       int64    1460        441      0           0.000
# TotalBsmtSF      int64    1460        721      0           0.000
# 1stFlrSF         int64    1460        753      0           0.000
# FullBath         int64    1460          4      0           0.000
# TotRmsAbvGrd     int64    1460         12      0           0.000
# YearBuilt        int64    1460        112      0           0.000
# YearRemodAdd     int64    1460         61      0           0.000
# GarageYrBlt    float64    1379         98     81           5.548
# MasVnrArea     float64    1452        328      8           0.548
# Fireplaces       int64    1460          4      0           0.000
# BsmtFinSF1       int64    1460        637      0           0.000
# LotFrontage    float64    1201        111    259          17.740
# WoodDeckSF       int64    1460        274      0           0.000
# 2ndFlrSF         int64    1460        417      0           0.000
# OpenPorchSF      int64    1460        202      0           0.000
# HalfBath         int64    1460          3      0           0.000
# LotArea          int64    1460       1073      0           0.000
# BsmtFullBath     int64    1460          4      0           0.000
# BsmtUnfSF        int64    1460        780      0           0.000
# BedroomAbvGr     int64    1460          8      0           0.000
# ScreenPorch      int64    1460         76      0           0.000
# PoolArea         int64    1460          8      0           0.000
# MoSold           int64    1460         12      0           0.000
# 3SsnPorch        int64    1460         20      0           0.000
# BsmtFinSF2       int64    1460        144      0           0.000
# BsmtHalfBath     int64    1460          3      0           0.000
# ...                ...     ...        ...    ...             ...
# RoofStyle       object    1460          6      0           0.000
# RoofMatl        object    1460          8      0           0.000
# Exterior1st     object    1460         15      0           0.000
# Exterior2nd     object    1460         16      0           0.000
# MasVnrType      object    1452          5      8           0.548
# ExterQual       object    1460          4      0           0.000
# ExterCond       object    1460          5      0           0.000
# Foundation      object    1460          6      0           0.000
# BsmtQual        object    1423          5     37           2.534
# BsmtCond        object    1423          5     37           2.534
# BsmtExposure    object    1422          5     38           2.603
# BsmtFinType1    object    1423          7     37           2.534
# BsmtFinType2    object    1422          7     38           2.603
# Heating         object    1460          6      0           0.000
# HeatingQC       object    1460          5      0           0.000
# CentralAir      object    1460          2      0           0.000
# Electrical      object    1459          6      1           0.068
# KitchenQual     object    1460          4      0           0.000
# Functional      object    1460          7      0           0.000
# FireplaceQu     object     770          6    690          47.260
# GarageType      object    1379          7     81           5.548
# GarageFinish    object    1379          4     81           5.548
# GarageQual      object    1379          6     81           5.548
# GarageCond      object    1379          6     81           5.548
# PavedDrive      object    1460          3      0           0.000
# PoolQC          object       7          4   1453          99.521
# Fence           object     281          5   1179          80.753
# MiscFeature     object      54          5   1406          96.301
# SaleType        object    1460          9      0           0.000
# SaleCondition   object    1460          6      0           0.000
#
#                                                          uniques  skewness  \
# SalePrice      [[208500, 181500, 223500, 140000, 250000, 1430...     1.883
# OverallQual                    [[7, 6, 8, 5, 9, 4, 10, 3, 1, 2]]     0.217
# GrLivArea      [[1710, 1262, 1786, 1717, 2198, 1362, 1694, 20...     1.367
# GarageCars                                     [[2, 3, 1, 0, 4]]    -0.343
# GarageArea     [[548, 460, 608, 642, 836, 480, 636, 484, 468,...     0.180
# TotalBsmtSF    [[856, 1262, 920, 756, 1145, 796, 1686, 1107, ...     1.524
# 1stFlrSF       [[856, 1262, 920, 961, 1145, 796, 1694, 1107, ...     1.377
# FullBath                                          [[2, 1, 3, 0]]     0.037
# TotRmsAbvGrd          [[8, 6, 7, 9, 5, 11, 4, 10, 12, 3, 2, 14]]     0.676
# YearBuilt      [[2003, 1976, 2001, 1915, 2000, 1993, 2004, 19...    -0.613
# YearRemodAdd   [[2003, 1976, 2002, 1970, 2000, 1995, 2005, 19...    -0.504
# GarageYrBlt    [[2003.0, 1976.0, 2001.0, 1998.0, 2000.0, 1993...    -0.649
# MasVnrArea     [[196.0, 0.0, 162.0, 350.0, 186.0, 240.0, 286....     2.669
# Fireplaces                                        [[0, 1, 2, 3]]     0.650
# BsmtFinSF1     [[706, 978, 486, 216, 655, 732, 1369, 859, 0, ...     1.686
# LotFrontage    [[65.0, 80.0, 68.0, 60.0, 84.0, 85.0, 75.0, na...     2.164
# WoodDeckSF     [[0, 298, 192, 40, 255, 235, 90, 147, 140, 160...     1.541
# 2ndFlrSF       [[854, 0, 866, 756, 1053, 566, 983, 752, 1142,...     0.813
# OpenPorchSF    [[61, 0, 42, 35, 84, 30, 57, 204, 4, 21, 33, 2...     2.364
# HalfBath                                             [[1, 0, 2]]     0.676
# LotArea        [[8450, 9600, 11250, 9550, 14260, 14115, 10084...    12.208
# BsmtFullBath                                      [[1, 0, 2, 3]]     0.596
# BsmtUnfSF      [[150, 284, 434, 540, 490, 64, 317, 216, 952, ...     0.920
# BedroomAbvGr                          [[3, 4, 1, 2, 0, 5, 6, 8]]     0.212
# ScreenPorch    [[0, 176, 198, 291, 252, 99, 184, 168, 130, 14...     4.122
# PoolArea                [[0, 512, 648, 576, 555, 480, 519, 738]]    14.828
# MoSold                 [[2, 5, 9, 12, 10, 8, 11, 4, 1, 7, 3, 6]]     0.212
# 3SsnPorch      [[0, 320, 407, 130, 180, 168, 140, 508, 238, 2...    10.304
# BsmtFinSF2     [[0, 32, 668, 486, 93, 491, 506, 712, 362, 41,...     4.255
# BsmtHalfBath                                         [[0, 1, 2]]     4.103
# ...                                                          ...       ...
# RoofStyle           [[Gable, Hip, Gambrel, Mansard, Flat, Shed]]       nan
# RoofMatl       [[CompShg, WdShngl, Metal, WdShake, Membran, T...       nan
# Exterior1st    [[VinylSd, MetalSd, Wd Sdng, HdBoard, BrkFace,...       nan
# Exterior2nd    [[VinylSd, MetalSd, Wd Shng, HdBoard, Plywood,...       nan
# MasVnrType                 [[BrkFace, None, Stone, BrkCmn, nan]]       nan
# ExterQual                                     [[Gd, TA, Ex, Fa]]       nan
# ExterCond                                 [[TA, Gd, Fa, Po, Ex]]       nan
# Foundation          [[PConc, CBlock, BrkTil, Wood, Slab, Stone]]       nan
# BsmtQual                                 [[Gd, TA, Ex, nan, Fa]]       nan
# BsmtCond                                 [[TA, Gd, nan, Fa, Po]]       nan
# BsmtExposure                             [[No, Gd, Mn, Av, nan]]       nan
# BsmtFinType1               [[GLQ, ALQ, Unf, Rec, BLQ, nan, LwQ]]       nan
# BsmtFinType2               [[Unf, BLQ, nan, ALQ, Rec, LwQ, GLQ]]       nan
# Heating                  [[GasA, GasW, Grav, Wall, OthW, Floor]]       nan
# HeatingQC                                 [[Ex, Gd, TA, Fa, Po]]       nan
# CentralAir                                              [[Y, N]]       nan
# Electrical              [[SBrkr, FuseF, FuseA, FuseP, Mix, nan]]       nan
# KitchenQual                                   [[Gd, TA, Ex, Fa]]       nan
# Functional             [[Typ, Min1, Maj1, Min2, Mod, Maj2, Sev]]       nan
# FireplaceQu                          [[nan, TA, Gd, Fa, Ex, Po]]       nan
# GarageType     [[Attchd, Detchd, BuiltIn, CarPort, nan, Basme...       nan
# GarageFinish                              [[RFn, Unf, Fin, nan]]       nan
# GarageQual                           [[TA, Fa, Gd, nan, Ex, Po]]       nan
# GarageCond                           [[TA, Fa, nan, Gd, Po, Ex]]       nan
# PavedDrive                                           [[Y, N, P]]       nan
# PoolQC                                       [[nan, Ex, Fa, Gd]]       nan
# Fence                          [[nan, MnPrv, GdWo, GdPrv, MnWw]]       nan
# MiscFeature                      [[nan, Shed, Gar2, Othr, TenC]]       nan
# SaleType       [[WD, New, COD, ConLD, ConLI, CWD, ConLw, Con,...       nan
# SaleCondition  [[Normal, Abnorml, Partial, AdjLand, Alloca, F...       nan
#
#                kurtosis  corr SalePrice
# SalePrice         6.536           1.000
# OverallQual       0.096           0.791
# GrLivArea         4.895           0.709
# GarageCars        0.221           0.640
# GarageArea        0.917           0.623
# TotalBsmtSF      13.250           0.614
# 1stFlrSF          5.746           0.606
# FullBath         -0.857           0.561
# TotRmsAbvGrd      0.881           0.534
# YearBuilt        -0.440           0.523
# YearRemodAdd     -1.272           0.507
# GarageYrBlt      -0.418           0.486
# MasVnrArea       10.082           0.477
# Fireplaces       -0.217           0.467
# BsmtFinSF1       11.118           0.386
# LotFrontage      17.453           0.352
# WoodDeckSF        2.993           0.324
# 2ndFlrSF         -0.553           0.319
# OpenPorchSF       8.490           0.316
# HalfBath         -1.077           0.284
# LotArea         203.243           0.264
# BsmtFullBath     -0.839           0.227
# BsmtUnfSF         0.475           0.214
# BedroomAbvGr      2.231           0.168
# ScreenPorch      18.439           0.111
# PoolArea        223.268           0.092
# MoSold           -0.404           0.046
# 3SsnPorch       123.662           0.045
# BsmtFinSF2       20.113          -0.011
# BsmtHalfBath     16.397          -0.017
# ...                 ...             ...
# RoofStyle           nan             nan
# RoofMatl            nan             nan
# Exterior1st         nan             nan
# Exterior2nd         nan             nan
# MasVnrType          nan             nan
# ExterQual           nan             nan
# ExterCond           nan             nan
# Foundation          nan             nan
# BsmtQual            nan             nan
# BsmtCond            nan             nan
# BsmtExposure        nan             nan
# BsmtFinType1        nan             nan
# BsmtFinType2        nan             nan
# Heating             nan             nan
# HeatingQC           nan             nan
# CentralAir          nan             nan
# Electrical          nan             nan
# KitchenQual         nan             nan
# Functional          nan             nan
# FireplaceQu         nan             nan
# GarageType          nan             nan
# GarageFinish        nan             nan
# GarageQual          nan             nan
# GarageCond          nan             nan
# PavedDrive          nan             nan
# PoolQC              nan             nan
# Fence               nan             nan
# MiscFeature         nan             nan
# SaleType            nan             nan
# SaleCondition       nan             nan
#
# [80 rows x 9 columns]
